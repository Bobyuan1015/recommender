# %%
import pandas as pd
import numpy as np

newsdetail = pd.read_table('data/corrct_news_title_comment_like.txt',encoding='utf-8',sep=':!:')
newsdetail.head()
print(newsdetail.columns)
print(newsdetail.index)
print("len(newsdetail['id'].unique())=",len(newsdetail['id'].unique()),newsdetail.isnull().any(),"len=",len(newsdetail))
newsdetail.head(100)
# print('before index=',newsdetail.index)
# newsdetail.reindex(index=list(range(55742)))
# print('after index=',newsdetail.index)
# print(newsdetail['news_detail'][1])

# print(newsdetail['news_detail'][2])

# print(newsdetail['news_detail'][3])

# print(newsdetail['news_detail'][4])
# Out:
# /home/yuanf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead.
#   after removing the cwd from sys.path.
# /home/yuanf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-562527119090> in <module>
#       2 import numpy as np
#       3
# ----> 4 newsdetail = pd.read_table('data/corrct_news_title_comment_like.txt',encoding='utf-8',sep=':!:')
#       5 newsdetail.head()
#       6 print(newsdetail.columns)
#
# ...

# %%
import pandas as pd
df=pd.read_csv('data/user_click.txt')
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'nickname', 'name', 'sex', 'head_url', 'region',
#        'autograph', 'integral', 'is_big_v', 'is_first_login'],
#       dtype='object')

# %%
# s='nihao,shijie'
# >>> t='nihao'
# >>> result = t in s
fp = open('data/news_title_comment_like.txt', 'r')
fp1 = open('data/corrct_news_title_comment_like.txt', 'wb')
# enumerate()为枚举，i为行号从0开始，line为值
correctLines=[]
tmp=['']
# concatFlag=0
for i, line in enumerate(fp): 
#     if i < 2000:
        num = (len(line) - len(line.replace(':!:',""))) // len(':!:')
#         print('i=',i,'  num:!:=',num)
        if num == 10 :
#             correctLines.append(line)
#             fp.write(correctLines)
            print(' write:')
            fp1.write(bytes(line,'UTF-8'))
        else:
            tmp[len(tmp)-1]+=line.strip('\r\n')
            tempnum = (len(tmp[len(tmp)-1]) - len(tmp[len(tmp)-1].replace(':!:',""))) // len(':!:')
#             if i>1500 and i <1550:
#                 print('i=',i,'len(line)=',len(line),'len(tmp)=',len(tmp[len(tmp)-1]),'  tempnum:!:=',tempnum, '  num:!:=',num)
            if tempnum ==10:           
    #             print(' midddle:',tmp)
#                 correctLines.append(tmp)
                fp1.write(bytes(tmp[len(tmp)-1],'UTF-8'))                
                tmp.append('')
                print("append tempnum=",tempnum,'----len of tmp=',len(tmp[len(tmp)-1]),' index=',len(tmp)-1,' ',tmp[len(tmp)-1])
#             else:
#                 concatFlag=1
#                 tmp[len(tmp)-1]+=line.strip('\r\n')
#                 print("<10 tempnum=",tempnum,' line=',line,' index=',len(tmp)-1,'len of tmp=',len(tmp[len(tmp)-1]))
#                 tempnum = (len(tmp[len(tmp)-1]) - len(tmp[len(tmp)-1].replace(':!:',""))) // len(':!:')

# fp.close()

print("converting job is done, you can check the file.")

fp.close()
fp1.close()
# # import pandas as pd
# newsdetail = pd.read_table('data/corrct_news_title_comment_like.txt',encoding='utf-8',sep=':!:')
# newsdetail.head(100)
    
    # 计数
#     if i % 100000 == 0:
#     print ('loading %s(%s)' % (filename, i), file=sys.stderr)
# Out:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
# append tempnum= 10 ----len of tmp= 0  index= 1
# append tempnum= 10 ----len of tmp= 0  index= 2
#  write:
#  write:
#  write:
#  write:
#  write:
# append tempnum= 10 ----len of tmp= 0  index= 3
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
#  write:
# append tempnum= 10 ----len of tmp= 0  index= 4
# append tempnum= 10 ----len of tmp= 0  index= 5
# append tempnum= 10 ----len of tmp= 0  index= 6
# append tempnum= 10 ----len of tmp= 0  index= 7
# append tempnum= 10 ----len of tmp= 0  index= 8
# ...

# %%
fp = open('data/news_title_comment_like.txt', 'r')
fp1 = open('data/corrct_news_title_comment_like.txt', 'wb')
correctLines=[]
tmp=['']
for i, line in enumerate(fp): 
        num = (len(line) - len(line.replace(':!:',""))) // len(':!:')
        if num == 10 :
            print(' write:')
            fp1.write(bytes(line,'UTF-8'))
        else:
            tmp[len(tmp)-1]+=line.strip('\r\n')
            tempnum = (len(tmp[len(tmp)-1]) - len(tmp[len(tmp)-1].replace(':!:',""))) // len(':!:')
            if tempnum ==10:           
                fp1.write(bytes(tmp[len(tmp)-1],'UTF-8'))                
                tmp.append('')
                print("append tempnum=",tempnum,'----len of tmp=',len(tmp[len(tmp)-1]),' index=',len(tmp)-1,' ',tmp[len(tmp)-1])


print("converting job is done, you can check the file.")

fp.close()
fp1.close()

# %%
import pandas as pd
# newsdetail = pd.read_table('data/user_click.txt',encoding='utf-8',sep=':!:')
# print(newsdetail.columns)
# print(newsdetail.describe(),'   len=',len(newsdetail),'unique userid=',len(newsdetail.user_id.unique()),
#       ' unique newsid=',len(newsdetail.article_id.unique()))


newsdetail1 = pd.read_csv('data/clean_news.csv',encoding='utf-8')

print(newsdetail1.columns)
print(newsdetail1.describe(),'   len=',len(newsdetail1),' unique newsid=',len(newsdetail1.newsID.unique()))
# Out:
# Index(['Unnamed: 0', 'creator_id', 'news_title', 'news_subtitle',
#        'updated_year', 'updated_month', 'updated_day', 'updated_timestamp',
#        'newsID'],
#       dtype='object')
#         Unnamed: 0     creator_id  news_title  news_subtitle  updated_year  \
# count  2228.000000    2228.000000      2228.0    2228.000000        2228.0
# mean   1273.938061   10254.827199         1.0       0.998205        2019.0
# std     713.879119   22539.881459         0.0       0.042343           0.0
# min       0.000000       1.000000         1.0       0.000000        2019.0
# 25%     655.750000     233.000000         1.0       1.000000        2019.0
# 50%    1285.500000     507.000000         1.0       1.000000        2019.0
# 75%    1897.250000   13693.000000         1.0       1.000000        2019.0
# max    2481.000000  171053.000000         1.0       1.000000        2019.0
#
#        updated_month  updated_day  updated_timestamp       newsID
# ...

# %%
import os,sys
# !rm foo.txt
#打开文件
fd = open('foo.txt','wb')

# str = 'this is fujieace.com test'
# str = str.encode()

# #写入字符串
# os.write(fd,str)

# #关闭文件

for i in range(10):
    fd.write(bytes('y','UTF-8'))

# str = [bytes('y','UTF-8'),bytes('f','UTF-8'),bytes('bob','UTF-8')]
# fd.write(str)
fd.close()
# !cat foo.txt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-57c59e6d4298> in <module>
#       1 import os,sys
# ----> 2 get_ipython().system('rm foo.txt')
#       3 #打开文件
#       4 fd = open('foo.txt','wb')
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2444         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2445         # Instead, we store the exit_code in user_ns.
# -> 2446         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2447
#    2448     def system_raw(self, cmd):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# ...

# %%
# D={'name':'xiaodeng','age':28}
# print(D.setdefault('name'))              #xiaodeng
# print(D.setdefault('color','yellow'))
# print(D)
from collections import defaultdict

D={}
D.setdefault(1, defaultdict(int))
# Out:
# defaultdict(int, {})

# %%
test=pd.read_table('news_title_comment_like.txt',index_col=0)
print(test.columns.to_list())
test.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-041acd106141> in <module>
# ----> 1 test=pd.read_csv('news_title_comment_like.txt',index_col=0)
#       2 print(test.columns.to_list())
#       3 test.head(5)
#
# ...

# %%
print("null id number=",len(newsdetail['id'][newsdetail['id'].isnull()].index.to_list()))
print("before len =",len(newsdetail)," index=",newsdetail.index)
# merge2.dropna(axis=0, how='any', inplace=True)

newsdetail.drop(newsdetail.index[newsdetail['id'][newsdetail['id'].isnull()].index.to_list()],inplace=True)
newsdetail.index = range(0,len(newsdetail))

print("after drop len= ",len(newsdetail)," index=",newsdetail.index)
# newsdetail['id'][newsdetail['id'].isnull()].index.to_list()
# Out:
# null id number= 58
# before len = 55800  index= RangeIndex(start=0, stop=55800, step=1)
# after drop len=  55742  index= RangeIndex(start=0, stop=55742, step=1)

# %%
print("after drop len= ",len(newsdetail)," index=",newsdetail.index)

print("null news_detail number=",len(newsdetail['news_detail'][newsdetail['news_detail'].isnull()].index.to_list()))
print("before len =",len(newsdetail)," index=",newsdetail.index)
# print("null:",newsdetail['news_detail'][newsdetail['news_detail'].isnull()])
newsdetail.drop(newsdetail.index[newsdetail['news_detail'][newsdetail['news_detail'].isnull()].index.to_list()],inplace=True)
newsdetail.index = range(0,len(newsdetail))

# newsdetail.reindex(range(len(newsdetail)))
print("after drop len= ",len(newsdetail)," index=",newsdetail.index)


newsd=newsdetail['id'].to_list()
print(newsd[:20])
newsdetail.head(100)
# Out:
# after drop len=  2996  index= RangeIndex(start=0, stop=2996, step=1)
# null news_detail number= 0
# before len = 2996  index= RangeIndex(start=0, stop=2996, step=1)
# after drop len=  2996  index= RangeIndex(start=0, stop=2996, step=1)
# ['82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', 'font-family:&quot;微软雅黑&quot;,sans-serif;mso-bidi-font-family:Calibri">高度赞赏<span lang="EN-US">U5</span>具备<span lang="EN-US">“</span>其他制造商无法媲美的品质！<span lang="EN-US">”</span></span><span lang="EN-US"><o:p></o:p></span></p>', '93', 'font-family:&quot;微软雅黑&quot;,sans-serif;mso-bidi-font-family:Calibri">高度赞赏<span lang="EN-US">U5</span>具备<span lang="EN-US">“</span>其他制造商无法媲美的品质！<span lang="EN-US">”</span></span><span lang="EN-US"><o:p></o:p></span></p>', '94', '95', '96', '97', '98', '99']
#                                                    id  \
# 0                                                  82
# 1                                                  83
# ...

# %%
newsd=newsdetail['id'].to_list()
print(newsd[:500])
# Out:
# ['82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', 'font-family:&quot;微软雅黑&quot;,sans-serif;mso-bidi-font-family:Calibri">高度赞赏<span lang="EN-US">U5</span>具备<span lang="EN-US">“</span>其他制造商无法媲美的品质！<span lang="EN-US">”</span></span><span lang="EN-US"><o:p></o:p></span></p>', '93', 'font-family:&quot;微软雅黑&quot;,sans-serif;mso-bidi-font-family:Calibri">高度赞赏<span lang="EN-US">U5</span>具备<span lang="EN-US">“</span>其他制造商无法媲美的品质！<span lang="EN-US">”</span></span><span lang="EN-US"><o:p></o:p></span></p>', '94', '95', '96', '97', '98', '99', '</style>', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '</style>', '142', '</style>', '143', '</style>', '144', '</p><p class="MsoNormal"><span lang="EN-USArial&quot;,sans-serif\'"><o:p>&nbsp;
# ...

# %%
# from pandas import DataFrame
# df1 = pd.DataFrame(np.random.rand(25).reshape([5, 5]), index=['A', 'B', 'D', 'E', 'F'], columns=['c1', 'c2', 'c3', 'c4', 'c5'])
# # print(df1)
# print('-----'*20)
# # # print(df.drop([1],axis = 0))
# df1.drop(df1.index[1])       # 删除第1行
# df1.index = range(0,len(df1))
# # df1.index=range(len(df1))

# # # df1.reindex(index=['1','2','3','4','5'])
# # df1.reindex(index=['A','B','C','D','E','F'])

# print(df1)
# # df1 = DataFrame(np.random.rand(25).reshape(5,5), index=['A','B','D','E','F'], columns=['c1','c2','c3','c4','c5'])

# # df3 = df2.rename(index={'beijing':'bj'}, columns = {'A':'aa'}) # 为某个 index 单独修改名称
# # print(df3) #
# # '''
# #            aa  B  C
# # bj          0  1  2
# # shanghai    3  4  5
# # guangzhou   6  7  8
# # '''

# # # 自定义map函数
# # def test_map(x):
# #     return x+'_ABC'

# # # print(df1.index.map(test_map))
# # # 输出 Index(['BEIJING_ABC', 'SHANGHAI_ABC', 'GUANGZHOU_ABC'], dtype='object')

# # print(df1.rename(index=test_map))

# # df1.rename(index=['1','B','C','D','E'])
# Out:
#          c1        c2        c3        c4        c5
# A  0.221616  0.339123  0.705486  0.460516  0.136787
# B  0.944592  0.360675  0.633584  0.722168  0.287489
# D  0.192498  0.773726  0.619847  0.105446  0.680293
# E  0.419276  0.714287  0.469713  0.172767  0.541414
# F  0.009756  0.321866  0.020725  0.717165  0.634547
# ----------------------------------------------------------------------------------------------------
#          c1        c2        c3        c4        c5
# 0  0.221616  0.339123  0.705486  0.460516  0.136787
# 1  0.944592  0.360675  0.633584  0.722168  0.287489
# 2  0.192498  0.773726  0.619847  0.105446  0.680293
# 3  0.419276  0.714287  0.469713  0.172767  0.541414
# 4  0.009756  0.321866  0.020725  0.717165  0.634547
